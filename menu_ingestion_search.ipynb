# %% [markdown]
# # Azure OpenAI and AI Search Pipeline for Menu Ingestion
#
# ## 1: Notebook Introduction
# This notebook demonstrates how to:
# 1. Extract text from a menu PDF using OCR.
# 2. Parse the extracted text using GPT-4o into structured JSON format.
# 3. Configure Azure OpenAI and Azure AI Search services.
# 4. Prepare the parsed data for ingestion into Azure AI Search.
# 5. Upload the prepared data to Azure AI Search for hybrid semantic search capabilities.

# %% [markdown]
# ## 2: Imports and Environment Setup
#
# ### Description
# This cell imports necessary libraries and loads environment variables using `dotenv`.
# Ensure your `.env` file is properly set up with the required Azure API keys and endpoints.

# %%
# Import required libraries
from azure.core.credentials import AzureKeyCredential
from azure.core.exceptions import HttpResponseError
from azure.search.documents import SearchClient
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import (
    SearchIndex,
    SimpleField,
    SearchField,
    SearchFieldDataType,
    VectorSearch,
    HnswAlgorithmConfiguration,
    VectorSearchProfile,
    AzureOpenAIVectorizer,
    AzureOpenAIVectorizerParameters,
    SemanticConfiguration,
    SemanticPrioritizedFields,
    SemanticField,
    SemanticSearch
)
from dotenv import load_dotenv
from langchain_community.vectorstores.azuresearch import AzureSearch
from langchain_openai import AzureOpenAIEmbeddings
from langchain_community.document_loaders import PyPDFLoader
from openai import AzureOpenAI
from pydantic import BaseModel
from tenacity import retry, stop_after_attempt, wait_exponential
from typing import List

import base64
import json
import os
import openai
import re

# Load environment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 3: Azure OpenAI and Azure AI Search Configuration
#
# ### Description
# This cell sets up the Azure OpenAI and AI Search configurations, including the embeddings and vector store.
# Ensure that the endpoints, API keys, and deployment names in the `.env` file match your Azure resource setup.

# %%
# Azure OpenAI setup
aoai_eastus_endpoint = os.getenv("AZURE_OPENAI_EASTUS_ENDPOINT")
aoai_eastus_api_key = os.getenv("AZURE_OPENAI_EASTUS_API_KEY")
aoai_gpt4o_deployment = os.getenv("AZURE_OPENAI_GPT4O_DEPLOYMENT")
aoai_gpt4o_mini_deployment = os.getenv("AZURE_OPENAI_GPT4O_MINI_DEPLOYMENT")
aoai_openai_api_version = os.getenv("AZURE_OPENAI_API_VERSION")
aoai_embedding_deployment = os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT")

# Initialize the Azure OpenAI client
aoai_client = AzureOpenAI(
    azure_endpoint=aoai_eastus_endpoint,
    api_version=aoai_openai_api_version,
    api_key=aoai_eastus_api_key,
)

# Azure AI Search credentials
search_service_endpoint = os.getenv("AZURE_SEARCH_ENDPOINT")  # Replace with your Azure Cognitive Search endpoint
search_api_key = os.getenv("AZURE_SEARCH_KEY")  # Replace with your Azure Cognitive Search API key
index_name = os.getenv("INDEX_NAME")  # Replace with your Azure Cognitive Search index name
search_client = SearchClient(endpoint=search_service_endpoint, index_name=index_name, credential=AzureKeyCredential(search_api_key))
search_index_client = SearchIndexClient(endpoint=search_service_endpoint, index_name=index_name, credential=AzureKeyCredential(search_api_key))


# Define and Create/Update Index Schema with Semantic Configuration
index_schema = SearchIndex(
    name=index_name,
    fields=[
        SimpleField(name="id", type=SearchFieldDataType.String, key=True, sortable=True, filterable=True, facetable=True),
        SearchField(name="category", type=SearchFieldDataType.String, sortable=True, filterable=True, facetable=True),
        SearchField(name="item", type=SearchFieldDataType.String, sortable=True, filterable=True, facetable=True),
        SearchField(name="description", type=SearchFieldDataType.String),
        SimpleField(name="price", type=SearchFieldDataType.String, sortable=True, filterable=True, facetable=True),

        SearchField(name="embedding", type=SearchFieldDataType.Collection(SearchFieldDataType.Single), vector_search_dimensions=3072, vector_search_profile_name="myHnswProfile")
    ],
    vector_search=VectorSearch(
        algorithms=[
            HnswAlgorithmConfiguration(
                name="myHnsw",
                kind="hnsw",
                parameters={
                    "m": 10, # Number of neighbors, higher values improve accuracy at the cost of memory
                    "efConstruction": 200 # Larger value improves recall but increases indexing time
                }
            )
        ],
        profiles=[
            VectorSearchProfile(
                name="myHnswProfile",
                algorithm_configuration_name="myHnsw",
                vectorizer_name="myVectorizer"
            )
        ],
        vectorizers=[
            AzureOpenAIVectorizer(
                vectorizer_name="myVectorizer",
                parameters=AzureOpenAIVectorizerParameters(
                    resource_url=aoai_eastus_endpoint,
                    deployment_name=aoai_embedding_deployment,
                    model_name=aoai_embedding_deployment,
                    api_key=aoai_eastus_api_key
                )
            )
        ]
    ),
    semantic_search=SemanticSearch(
        configurations=[SemanticConfiguration(
            name="mySemanticConfig",
            prioritized_fields=SemanticPrioritizedFields(
                title_field=SemanticField(field_name="item"),
                content_fields=[
                    SemanticField(field_name="description")
                ]
            )
        )]
    ),
)

# Delete the existing index if it exists
try:
    search_index_client.delete_index(index_name)
    print(f"Deleted existing index: {index_name}")
except Exception as e:
    print(f"Index {index_name} does not exist or could not be deleted: {e}")

search_index_client.create_or_update_index(index=index_schema)
print(f"Created index: {index_name}")
# Out:
# Deleted existing index: coffee-chat
# Created index: coffee-chat

# %% [markdown]
# ## 4: Define GPT-4o Parsing Function
#
# ### Description
# This function sends the extracted menu text to GPT-4o via Azure OpenAI to parse it into structured JSON format.
# The JSON includes fields like `category`, `item`, `description`, and `price`.

# %%
class CoffeeMenuItem(BaseModel):
    category: str
    item: str
    description: str
    price: str = None

class CoffeeMenu(BaseModel):
    items: List[CoffeeMenuItem]

def print_parsed_menu(parsed_menu):
    # Print the parsed menu in a formatted way
    if parsed_menu:
        for item in parsed_menu.items:
            print(f"Category: {item.category}")
            print(f"Item: {item.item}")
            print(f"Description: {item.description}")
            print(f"Price: {item.price}")
            print()  # Add a blank line between items

@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=5, max=60))
def parse_menu_with_gpt4o(raw_text, model_deployment_name):
    """Parse the raw text into structured JSON using GPT-4o."""
    prompt = f"""
    You are a menu parser. Convert the following raw text from a coffee menu into structured JSON with the fields:
    - category
    - item
    - description
    - price (if available)

    Here is the coffee menu text:
    ---
    {raw_text}
    ---
    """
    try:
        response = aoai_client.beta.chat.completions.parse(
            model=model_deployment_name,
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": prompt}
            ],
            # max_tokens=1500,
            temperature=0,
            response_format=CoffeeMenu
        )

        parsed_output = response.choices[0].message.parsed
        return parsed_output

    except openai.ContentFilterFinishReasonError as e:
        print(f"Content filter error: {e}")
        print(f"Problematic prompt: {prompt}")
        return None

# Example usage
sample_raw_text = """
Espresso Drinks
- Espresso: A strong coffee brewed by forcing hot water under pressure through finely ground coffee beans. $2.99
- Cappuccino: Espresso with steamed milk and a layer of foam. $3.99

Cold Brews
- Cold Brew: Coffee brewed cold for a smooth, rich flavor. $4.99
- Nitro Cold Brew: Cold brew infused with nitrogen for a creamy texture. $5.99
"""

parsed_menu = parse_menu_with_gpt4o(sample_raw_text, aoai_gpt4o_mini_deployment)
# print(parsed_menu)

print_parsed_menu(parsed_menu)
# Out:
# Category: Espresso Drinks
# Item: Espresso
# Description: A strong coffee brewed by forcing hot water under pressure through finely ground coffee beans.
# Price: $2.99
#
# Category: Espresso Drinks
# Item: Cappuccino
# Description: Espresso with steamed milk and a layer of foam.
# Price: $3.99
#
# Category: Cold Brews
# Item: Cold Brew
# Description: Coffee brewed cold for a smooth, rich flavor.
# Price: $4.99
#
# Category: Cold Brews
# Item: Nitro Cold Brew
# Description: Cold brew infused with nitrogen for a creamy texture.
# Price: $5.99

# %% [markdown]
# ## 5: Extract Text from PDF
#
# ### Description
# This cell uses `pdf2image` to convert each page of the provided PDF file into an image. It then uses `pytesseract` to perform Optical Character Recognition (OCR) on each image to extract the text. The extracted text from all pages is combined into a single string for further processing.

# %%
import pytesseract
from pdf2image import convert_from_path

def extract_text_from_pdf_images(pdf_path):
    """Extract text from images in a PDF file using OCR."""
    # Convert PDF pages to images
    images = convert_from_path(pdf_path)

    # Perform OCR on each image
    text = ""
    for image in images:
        text += pytesseract.image_to_string(image)

    return text

# Extract raw text from PDF images
pdf_path = "coffee-chat-beverage-menu.pdf"
raw_text = extract_text_from_pdf_images(pdf_path)

print(raw_text)
# Out:
# Beverage Menu View Text Menu
#
# 4 Menus Available
# (COFFEE SPECIALTIES)
#
# Intermezzo House Coffee... Proudly serving
# Dancing Goats coffee. Priced for each
# kannchen 4.00
#
# Coffee Infusion... “French Press” infused at
# your table (about 3 cups; please wait 2 minutes
# to push the press). 5.00
#
# Espresso... la créme de café ... The essence of
# pure, rich coffee 2.90
#
# Espresso Doppio... Double espresso 4.00
#
# Caffé Americano... Double espresso diluted
# with purified water 4.00
#
# Turkish Coffee...
#
# Pulverized light roast beans blended with
# cardamon and sugar, boiled 3 times, as served in
# Kolschitsky’s Coffeehouse in Vienna from 1683,
# and throughtout Arab and Greek nations. In
# contradiction to the famous story of Mr.
# Kolschitsky, the first recorded coffee-serving
# privilege in Vienna was granted in 1685 to an
# Armenian merchant named Deodato.
#
# (Notice: The grounds remain in the pot, some
# passing into your cup, making this extremely
# rich, sip slowly.) 6.00
#
# Café Cubano... Double-rich espresso extraction
# with caramelized sugar 4.50
# CHILLED COFFEES
#
# Café Johannes... Espresso doppio over two
# scoops of vanilla ice cream, with Schlag 8.50
#
# Caffé Alpine... Espresso, white chocolate and
# cream, all over ice 6.50
#
# Granita Cappuccino... Granules of sugar and
# ice mixed with espresso, cream, cocoa, and
# Schlag 7.90 Add Vanilla Vodka +6.00
# ( COFFEES WITH ALCOHOL 3
#
# Bailey’s Cappuccino... Espresso, créme de
# caffé, with steamed cream, Bailey’s Irish Cream
# Liqueur and Schlag 12.50
#
# Café Dolce Vita... Cappuccino with Irish Cream
# and hazelnut liqueurs, over ice 12.00
#
# Café Nocciola... Cappuccino Italiano with coffee
# and hazelnut liqueurs 12.00
#
# Café Royale...Intermezzo House coffee with
# brandy and Schlag 11.50
#
# Café Salzburg... Espresso, milk, chocolate,
# vanilla, and Tuaca Vanilla/Herb Liqueur 12.00
#
# Caffé Corretto... Espresso créme de café with
# 1 oz. Sambuca or Grappa served on the side
# 11.00
#
# Caffé Light & Dark... Créme de Cocoa with
# espresso, cream and ice 11.50
#
# Cappuccino La Scala... Cappuccino Italaino
# with chocolate and almond liquer 12.00
#
# Cioccolate Calda Firenze... Hot Chocolate
# Deluxe with Tuaca Vanilla/ Herb liqueur. 13.00
#
# lrish Coffee... Café Intermezzo House Coffee,
# Irish Whiskey and whipped cream. 11.50
#
# The Joe Cartwright... vu ~ pvorten Advockaat
# IQUEUr, vanilla ICe Cream, Espresso, and vanilla
# syrup. Ponderously great! In honor of a wonderful
# friend! 13.00
#
# Kahlua Coffee... Café Intermezzo House
# Coffee with Kahlua coffee liqueur (with or without
# Schlag) 11.50
#
# North Face... Hot Chocolate Deluxe with
# Peppermint Schnapps, in a large cup. 13.00
#
# Page One... Cappuccino with Hazelnut-chocolate
# spread and Hazelnut liqueur 12.00
# (CAPPUCCINOS & CAFFE LATTES |
#
# Cappuccino Italiano... Espresso and steamed
# cream with froth.
# Classico (Reg) 5.00 Generoso (Lrg) 8.50
#
# Intermezzo Cappuccino... Espresso, the
# essence of coffee, with steamed cream, cocoa, all
# topped with fresh whipped cream & cinnamon.
# Classico (Reg) 5.90 Generoso (Lrg) 9.00
#
# Caffé Latte... Espresso créme de café with steamed
# milk Classico (Reg) 5.00 Generoso (Lrg) 8.50
#
# Caffé Intermezzo... Espresso with steamed cream,
# essence of almond, cocoa powder and almond
# slices. Classico (Reg) 6.30 Generoso (Lrg) 9.50
#
# Caramel Cappuccino... Espresso créme de caffé
# with steamed cream and caramel, topped with
# Schlag. Classico (Reg) 6.30 Generoso (Lrg) 9.50
#
# Cioccoloccino... Rich, pure Dutch Chocolate
# steamed in cream, added to espresso with Schlag
# and cocoa powder
#
# Classico (Reg) 6.70 Generoso (Lrg) 9.80
#
# Cioccoloccino Bianco... Dutch White
# chocolate steamed in cream and milk with
# espresso and Schlag.
#
# Classico (Reg) 6.70 Generoso (Lrg) 10.00
#
# Cubano Latte... Café Cubano with steamed
# milk. Classico (Reg) 5.99 Ganeroso (Lrg) 8.50
# Cappuccino Gianduja... (pronounced “John-do-ya”)
# Espresso with frothed cream, cocoa and hazelnut
# spread. Classico (Reg) 7.20 Generoso (Lrg) 10.25
#
# Cappuccino L’Amore... Cappuccino with flavors of
# brandy and rum plue fresh Schlag and cocoa
# powder. Classico (Reg) 6.30 Generoso (Lrg) 9.50
#
# Capuchio Brio... espresso steamedcream,
# cinnamon, sugar, vanilla, almond oil, brandy and rum
# flavors, and orange extracts with Schlag. “Capuchio
# Brio” means “happy toga” which emanates from
# Capuchin Monks, after whom cappuccino was
# named. Classico (Reg) 6.30 Generoso (Lrg) 9.50
#
# Caffé Bach... Espresso with steamed cream and
# butterscotch, topped with Schlag and butterscotch.
# Classico (Reg) 6.50 Generoso (Lrg) 9.50
#
# Caffé Mozart... Double espresso with fresh whipped
# cream and chocolate chips. Classico (Reg) 5.50
# Hot Chocolate DeLuxe... Rich steamed cream
# and milk, Dutch chocolate, fresh Schlag, and
# shaved dark chocolate 7.90
#
# Intermezzo Hot Chocolate... Rich steamed
# cream, Dutch chocolate, fresh Schlag, and the
# essence of almond 7.00
#
# Hot Chocolate Berlin... Hazelnut-chocolate
# spread with steamed cream 8.50
#
# White Hot Chocolate DeLuxe... Steamed
# cream and milk with Dutch white chocolate and
# vanilla 7.90
#
# Mexican Hot Chocolate... Semi-sweet dark
# chocolate, mexican vanilla, milk and cinnamon.
# 8.00
#
# Hot Chocolate Deluxe Truffle... Hot Chocolate
# Deluxe with caramel syrup 8.00
#
# Chocolate Peanut Butter Cup... Steamed
# cream, Dutch chocolate, and peanut butter with
# fresh Schlag 7.90
#
# SODAS AND JUICES J
#
# Coca-Cola... bottle 8 oz. classic (regular or diet)
# 2.75
# Sprite... 8 oz. bottle 2.75
#
# Iced Tea... House recipe blended and brewed
# with fresh leaf teas, unsweetened or sweetened
# 2.95
#
# Orange Juice... 3.00
#
# Panna Water, (still), Italy, 500 ml. 4.25, 1 liter
# 6.50
#
# San Pellegrino Water, 500 ml. 4.25, 1 liter 6.50
# C BEERS 7]
#
# Stella Artois, Belgium, 12 0z. 5.25
#
# SweetWater 420 Extra Pale Ale, Atlanta, 5.6 %,
# 12 oz. 5.50
#
# Blue Moon Belgian White, Denver, 12 oz. 5.90
#
# Erdinger Hefe-Weizen, (Wheat), Germany, 11.2
# oz. 7.50
#
# Peroni, Nastro Azzuro, Italy, 11.2 oz 6.00
#
# Guinness Pub Draught, Ireland (Nitrogen can)
# 14.9 oz. 6.50
#
# Heineken 0.0 Non- Alcoholic 11 0z. 6.25
#
# Athletic Brewing Upside Dawn 0.0 Non-
# Alcoholic Beer 12 0z. 6.50
#
# [ TEAS
#
# A pot of hot tea freshly infused to your order
# from whole leaf tea 4.25.
#
# A pot of hot water 1.50
#
# Sugar and cream are available upon request at no charge.
# Add Honey $1
#
# BLACK HERBAL
# Cochin Masala Chai Berry Berry
# Decaffeinated Chai
#
# Caramel Cream
# Earl Grey Casablanca
# English Breakfast Egyptian Chamomile
# OUTDO RES EE) Ginger Bounce Rooibos
# Lemon Ginger g .
# Mango Mango rreen Rootes
# Night of the Iguana Chocolate Chai go
# Peppermint
# Vanna thai Rooibos Provence
# Rooibos Chai
# Rosehip
# GREEN
# Jasmine
#
# Sencha Kyoto Cherry Rose
# q CHAMPAGNE COCKTAILS 7]
#
# Champagne Flight 22
#
# Choose 3 from any of the following champange
# cocktails
#
# Mimosa... Orange juice and sparkling wine 10
#
# Bellini... Peach nectar and sparkling wine 10
#
# Hawaiian Mimosa... Pineapple juice, coconut
# rum and sparkling wine 10
#
# Buona Fortuna... Strawberry puree, Strawberry
# schnapps with sparkling wine 10
#
# Cara Mia... Mango nectar and sparkling wine 10
#
# Festa Limone... Sparkling wine and Limoncello
# 10
#
# Kir Royale... sparkling wine with Creme de
# Cassis 10
#
# London Special... sparkling wine with bitters and
# sugar 10
#
# (CHAMPAGNES & SPARKLING WINES]
#
# Lunetta, Prosecco Brut,
# Italy, 187ml. 16 750ml. 59
#
# Santa Maria, Prose 3e,
# Italv. Bottle 750 ml. 38
# coy wre er tt ee
#
# Prince de Richemont, Brut Blanc de Blancs,
# France, . Glass 9.25 Bottle 750ml. 32
#
# Villa Pozzi, Sicilla Moscato, Italy,
# Glass 10.50
#
# Innocent Bystander Pink Moscato...
# Glass 11
#
# Domaine Chandon Brut...
# Califronia, 187 ml. 19
#
# Freixenet Cordon Negro Brut...
# Spain, 187ml. 12 750ml. 42
#
# Veuve de Clicquot 375 ml. 92
# Moét e Chandon 750 mi. 162
#
# Mirabello Prosecco, Italy, Bottle 750ml. 35
# q COCKTAILS 7]
#
# The Bill Naegele Watertower Deluxe Martini...
#
# A delicious concoction of Baileys Salted Caramel,
# coffee liqueurs, white and dark chocolate liqueurs,
# and vanilla vodka. Shaken with lots of ice, like the
# attitude of it namesake, who is a great friend of
# Brian Olson, and who provided opportunities which
# helped build the foundation of Cafe Intermezzo. 14
#
# Espresso Martini... Vanilla vodka, coffee liqueur,
# chocolate liqueur, and fresh espresso. 13.5
#
# French 75... Lemon, sugar, and Tanqueray Gin are
# shaken, strained and topped with champagne to
# recreate this timeless World War | era cocktail 15
#
# Peach Martini... Citrus vodka, peach schnapps,
# and peach nectar, topped with champagne. 13
#
# Sazerac... A New Orleans classic recreated with
# Redemption Rye, sugar, Peychaud’s bitters, and, of
# course, an absinthe rinse. Served neat. 14
#
# Aviation... Empress gin, maraschino liqueur, creme
# de violette, lemon juice, lemon peel. 14
#
# Old Fashioned... Sugar, bitters, orange slice, and
# cherry are paired with Michter’s Small Batch
# bourbon. 16
#
# B’Old Biddy... Bulleit Rye, paired with fresh lime
# juice, mint, cucumber, and St. Germain
# Elderflower liqueur. A refreshing cocktail that
# showcases the fresh ingredients and rye whiskey
# wonderfully. Served over ice. 14.5
#
# Paris on Fire... Grand Marnier, Chambord,
# pineapple juice, cranberry juice, and orange juice
# all over ice. 14
#
# Roasado Del Sol... Ron Zacapa Dark Rum,
# blackberry brandy, lemon juice, simple syrup, and a
# splash of orange juice 13
#
# Vi Olson “Inside Out”... A favorite of Brian Olson’s
# mother: a half lemon with a teaspoon of sugar,
# submerged in Tanqueray gin, muddled until its
# inside out, so that its essential oils flavor this
# delightful cocktail. 14
#
# Pimm’s Cup... Pimm’s #1, lemon, lime, orange,
# cucumber, and strawberry all muddled. 14
#
# Cucumber Martini... Hendrick’s gin, cucumber,
# lime and sugar. Stirred and strained. Crisp, bright
# and refreshing. 15
#
# Sidecar... Hennessy VSOP, orange liqueur, lemon
# and sugar. Shaken twice, strained, and served up.
# 18

# %% [markdown]
# ## 6: Parse Menu Data
#
# ### Description
# This cell sends the extracted raw text to the `parse_menu_with_gpt4o` function,
# returning structured JSON data ready for further processing.

# %%
# Parse menu with GPT-4o
parsed_menu = parse_menu_with_gpt4o(raw_text, aoai_gpt4o_mini_deployment)

print_parsed_menu(parsed_menu)
# Out:
# Category: Coffee Specialties
# Item: Intermezzo House Coffee
# Description: Proudly serving Dancing Goats coffee. Priced for each kannchen
# Price: 4.00
#
# Category: Coffee Specialties
# Item: Coffee Infusion
# Description: “French Press” infused at your table (about 3 cups; please wait 2 minutes to push the press).
# Price: 5.00
#
# Category: Coffee Specialties
# Item: Espresso
# Description: la créme de café ... The essence of pure, rich coffee
# Price: 2.90
#
# Category: Coffee Specialties
# Item: Espresso Doppio
# Description: Double espresso
# Price: 4.00
#
# Category: Coffee Specialties
# Item: Caffé Americano
# Description: Double espresso diluted with purified water
# Price: 4.00
#
# Category: Coffee Specialties
# Item: Turkish Coffee
# Description: Pulverized light roast beans blended with cardamon and sugar, boiled 3 times, as served in Kolschitsky’s Coffeehouse in Vienna from 1683, and throughtout Arab and Greek nations. In contradiction to the famous story of Mr. Kolschitsky, the first recorded coffee-serving privilege in Vienna was granted in 1685 to an Armenian merchant named Deodato. (Notice: The grounds remain in the pot, some passing into your cup, making this extremely rich, sip slowly.)
# Price: 6.00
#
# Category: Coffee Specialties
# Item: Café Cubano
# Description: Double-rich espresso extraction with caramelized sugar
# Price: 4.50
#
# Category: Chilled Coffees
# Item: Café Johannes
# Description: Espresso doppio over two scoops of vanilla ice cream, with Schlag
# Price: 8.50
#
# Category: Chilled Coffees
# Item: Caffé Alpine
# Description: Espresso, white chocolate and cream, all over ice
# Price: 6.50
#
# Category: Chilled Coffees
# Item: Granita Cappuccino
# Description: Granules of sugar and ice mixed with espresso, cream, cocoa, and Schlag
# Price: 7.90
#
# Category: Chilled Coffees
# Item: Bailey’s Cappuccino
# Description: Espresso, créme de caffé, with steamed cream, Bailey’s Irish Cream Liqueur and Schlag
# Price: 12.50
#
# Category: Chilled Coffees
# Item: Café Dolce Vita
# Description: Cappuccino with Irish Cream and hazelnut liqueurs, over ice
# Price: 12.00
#
# Category: Chilled Coffees
# Item: Café Nocciola
# Description: Cappuccino Italiano with coffee and hazelnut liqueurs
# Price: 12.00
#
# Category: Chilled Coffees
# Item: Café Royale
# Description: Intermezzo House coffee with brandy and Schlag
# Price: 11.50
#
# Category: Chilled Coffees
# Item: Café Salzburg
# Description: Espresso, milk, chocolate, vanilla, and Tuaca Vanilla/Herb Liqueur
# Price: 12.00
#
# Category: Chilled Coffees
# Item: Caffé Corretto
# Description: Espresso créme de café with 1 oz. Sambuca or Grappa served on the side
# Price: 11.00
#
# Category: Chilled Coffees
# Item: Caffé Light & Dark
# Description: Créme de Cocoa with espresso, cream and ice
# Price: 11.50
#
# Category: Chilled Coffees
# Item: Cappuccino La Scala
# Description: Cappuccino Italaino with chocolate and almond liquer
# Price: 12.00
#
# Category: Chilled Coffees
# Item: Cioccolate Calda Firenze
# Description: Hot Chocolate Deluxe with Tuaca Vanilla/ Herb liqueur.
# Price: 13.00
#
# Category: Chilled Coffees
# Item: Irish Coffee
# Description: Café Intermezzo House Coffee, Irish Whiskey and whipped cream.
# Price: 11.50
#
# Category: Chilled Coffees
# Item: The Joe Cartwright
# Description: vu ~ pvorten Advockaat IQUEUr, vanilla ICe Cream, Espresso, and vanilla syrup. Ponderously great! In honor of a wonderful friend!
# Price: 13.00
#
# Category: Chilled Coffees
# Item: Kahlua Coffee
# Description: Café Intermezzo House Coffee with Kahlua coffee liqueur (with or without Schlag)
# Price: 11.50
#
# Category: Chilled Coffees
# Item: North Face
# Description: Hot Chocolate Deluxe with Peppermint Schnapps, in a large cup.
# Price: 13.00
#
# Category: Chilled Coffees
# Item: Page One
# Description: Cappuccino with Hazelnut-chocolate spread and Hazelnut liqueur
# Price: 12.00
#
# Category: Cappuccinos & Caffe Lattes
# Item: Cappuccino Italiano
# Description: Espresso and steamed cream with froth.
# Price: Classico (Reg) 5.00, Generoso (Lrg) 8.50
#
# Category: Cappuccinos & Caffe Lattes
# Item: Intermezzo Cappuccino
# Description: Espresso, the essence of coffee, with steamed cream, cocoa, all topped with fresh whipped cream & cinnamon.
# Price: Classico (Reg) 5.90, Generoso (Lrg) 9.00
#
# Category: Cappuccinos & Caffe Lattes
# Item: Caffé Latte
# Description: Espresso créme de café with steamed milk
# Price: Classico (Reg) 5.00, Generoso (Lrg) 8.50
#
# Category: Cappuccinos & Caffe Lattes
# Item: Caffé Intermezzo
# Description: Espresso with steamed cream, essence of almond, cocoa powder and almond slices.
# Price: Classico (Reg) 6.30, Generoso (Lrg) 9.50
#
# Category: Cappuccinos & Caffe Lattes
# Item: Caramel Cappuccino
# Description: Espresso créme de caffé with steamed cream and caramel, topped with Schlag.
# Price: Classico (Reg) 6.30, Generoso (Lrg) 9.50
#
# Category: Cappuccinos & Caffe Lattes
# Item: Cioccoloccino
# Description: Rich, pure Dutch Chocolate steamed in cream, added to espresso with Schlag and cocoa powder
# Price: Classico (Reg) 6.70, Generoso (Lrg) 9.80
#
# Category: Cappuccinos & Caffe Lattes
# Item: Cioccoloccino Bianco
# Description: Dutch White chocolate steamed in cream and milk with espresso and Schlag.
# Price: Classico (Reg) 6.70, Generoso (Lrg) 10.00
#
# Category: Cappuccinos & Caffe Lattes
# Item: Cubano Latte
# Description: Café Cubano with steamed milk.
# Price: Classico (Reg) 5.99, Generoso (Lrg) 8.50
#
# Category: Cappuccinos & Caffe Lattes
# Item: Cappuccino Gianduja
# Description: (pronounced “John-do-ya”) Espresso with frothed cream, cocoa and hazelnut spread.
# Price: Classico (Reg) 7.20, Generoso (Lrg) 10.25
#
# Category: Cappuccinos & Caffe Lattes
# Item: Cappuccino L’Amore
# Description: Cappuccino with flavors of brandy and rum plue fresh Schlag and cocoa powder.
# Price: Classico (Reg) 6.30, Generoso (Lrg) 9.50
#
# Category: Cappuccinos & Caffe Lattes
# Item: Capuchio Brio
# Description: espresso steamedcream, cinnamon, sugar, vanilla, almond oil, brandy and rum flavors, and orange extracts with Schlag. “Capuchio Brio” means “happy toga” which emanates from Capuchin Monks, after whom cappuccino was named.
# Price: Classico (Reg) 6.30, Generoso (Lrg) 9.50
#
# Category: Cappuccinos & Caffe Lattes
# Item: Caffé Bach
# Description: Espresso with steamed cream and butterscotch, topped with Schlag and butterscotch.
# Price: Classico (Reg) 6.50, Generoso (Lrg) 9.50
#
# Category: Cappuccinos & Caffe Lattes
# Item: Caffé Mozart
# Description: Double espresso with fresh whipped cream and chocolate chips.
# Price: Classico (Reg) 5.50
#
# Category: Hot Chocolate
# Item: Hot Chocolate DeLuxe
# Description: Rich steamed cream and milk, Dutch chocolate, fresh Schlag, and shaved dark chocolate
# Price: 7.90
#
# Category: Hot Chocolate
# Item: Intermezzo Hot Chocolate
# Description: Rich steamed cream, Dutch chocolate, fresh Schlag, and the essence of almond
# Price: 7.00
#
# Category: Hot Chocolate
# Item: Hot Chocolate Berlin
# Description: Hazelnut-chocolate spread with steamed cream
# Price: 8.50
#
# Category: Hot Chocolate
# Item: White Hot Chocolate DeLuxe
# Description: Steamed cream and milk with Dutch white chocolate and vanilla
# Price: 7.90
#
# Category: Hot Chocolate
# Item: Mexican Hot Chocolate
# Description: Semi-sweet dark chocolate, mexican vanilla, milk and cinnamon.
# Price: 8.00
#
# Category: Hot Chocolate
# Item: Hot Chocolate Deluxe Truffle
# Description: Hot Chocolate Deluxe with caramel syrup
# Price: 8.00
#
# Category: Hot Chocolate
# Item: Chocolate Peanut Butter Cup
# Description: Steamed cream, Dutch chocolate, and peanut butter with fresh Schlag
# Price: 7.90
#
# Category: Sodas and Juices
# Item: Coca-Cola
# Description: bottle 8 oz. classic (regular or diet)
# Price: 2.75
#
# Category: Sodas and Juices
# Item: Sprite
# Description: 8 oz. bottle
# Price: 2.75
#
# Category: Sodas and Juices
# Item: Iced Tea
# Description: House recipe blended and brewed with fresh leaf teas, unsweetened or sweetened
# Price: 2.95
#
# Category: Sodas and Juices
# Item: Orange Juice
# Description:
# Price: 3.00
#
# Category: Sodas and Juices
# Item: Panna Water
# Description: (still), Italy, 500 ml.
# Price: 4.25
#
# Category: Sodas and Juices
# Item: Panna Water
# Description: 1 liter
# Price: 6.50
#
# Category: Sodas and Juices
# Item: San Pellegrino Water
# Description: 500 ml.
# Price: 4.25
#
# Category: Sodas and Juices
# Item: San Pellegrino Water
# Description: 1 liter
# Price: 6.50
#
# Category: Beers
# Item: Stella Artois
# Description: Belgium, 12 oz.
# Price: 5.25
#
# Category: Beers
# Item: SweetWater 420 Extra Pale Ale
# Description: Atlanta, 5.6 %, 12 oz.
# Price: 5.50
#
# Category: Beers
# Item: Blue Moon Belgian White
# Description: Denver, 12 oz.
# Price: 5.90
#
# Category: Beers
# Item: Erdinger Hefe-Weizen
# Description: (Wheat), Germany, 11.2 oz.
# Price: 7.50
#
# Category: Beers
# Item: Peroni, Nastro Azzuro
# Description: Italy, 11.2 oz
# Price: 6.00
#
# Category: Beers
# Item: Guinness Pub Draught
# Description: Ireland (Nitrogen can) 14.9 oz.
# Price: 6.50
#
# Category: Beers
# Item: Heineken 0.0 Non- Alcoholic
# Description: 11 oz.
# Price: 6.25
#
# Category: Beers
# Item: Athletic Brewing Upside Dawn 0.0 Non-Alcoholic Beer
# Description: 12 oz.
# Price: 6.50
#
# Category: Teas
# Item: A pot of hot tea
# Description: freshly infused to your order from whole leaf tea
# Price: 4.25
#
# Category: Teas
# Item: A pot of hot water
# Description:
# Price: 1.50
#
# Category: Teas
# Item: Sugar and cream
# Description: are available upon request at no charge. Add Honey
# Price: $1
#
# Category: Champagne Cocktails
# Item: Champagne Flight
# Description: Choose 3 from any of the following champange cocktails
# Price: 22
#
# Category: Champagne Cocktails
# Item: Mimosa
# Description: Orange juice and sparkling wine
# Price: 10
#
# Category: Champagne Cocktails
# Item: Bellini
# Description: Peach nectar and sparkling wine
# Price: 10
#
# Category: Champagne Cocktails
# Item: Hawaiian Mimosa
# Description: Pineapple juice, coconut rum and sparkling wine
# Price: 10
#
# Category: Champagne Cocktails
# Item: Buona Fortuna
# Description: Strawberry puree, Strawberry schnapps with sparkling wine
# Price: 10
#
# Category: Champagne Cocktails
# Item: Cara Mia
# Description: Mango nectar and sparkling wine
# Price: 10
#
# Category: Champagne Cocktails
# Item: Festa Limone
# Description: Sparkling wine and Limoncello
# Price: 10
#
# Category: Champagne Cocktails
# Item: Kir Royale
# Description: sparkling wine with Creme de Cassis
# Price: 10
#
# Category: Champagne Cocktails
# Item: London Special
# Description: sparkling wine with bitters and sugar
# Price: 10
#
# Category: Champagnes & Sparkling Wines
# Item: Lunetta, Prosecco Brut
# Description: Italy, 187ml.
# Price: 16
#
# Category: Champagnes & Sparkling Wines
# Item: Santa Maria, Prose
# Description: Italy. Bottle 750 ml.
# Price: 38
#
# Category: Champagnes & Sparkling Wines
# Item: Prince de Richemont, Brut Blanc de Blancs
# Description: France, . Glass
# Price: 9.25
#
# Category: Champagnes & Sparkling Wines
# Item: Prince de Richemont, Brut Blanc de Blancs
# Description: Bottle 750ml.
# Price: 32
#
# Category: Champagnes & Sparkling Wines
# Item: Villa Pozzi, Sicilla Moscato
# Description: Italy, Glass
# Price: 10.50
#
# Category: Champagnes & Sparkling Wines
# Item: Innocent Bystander Pink Moscato
# Description:
# Price: 11
#
# Category: Champagnes & Sparkling Wines
# Item: Domaine Chandon Brut
# Description: Califronia, 187 ml.
# Price: 19
#
# Category: Champagnes & Sparkling Wines
# Item: Freixenet Cordon Negro Brut
# Description: Spain, 187ml.
# Price: 12
#
# Category: Champagnes & Sparkling Wines
# Item: Freixenet Cordon Negro Brut
# Description: 750ml.
# Price: 42
#
# Category: Champagnes & Sparkling Wines
# Item: Veuve de Clicquot
# Description: 375 ml.
# Price: 92
#
# Category: Champagnes & Sparkling Wines
# Item: Moét e Chandon
# Description: 750 ml.
# Price: 162
#
# Category: Cocktails
# Item: The Bill Naegele Watertower Deluxe Martini
# Description: A delicious concoction of Baileys Salted Caramel, coffee liqueurs, white and dark chocolate liqueurs, and vanilla vodka. Shaken with lots of ice, like the attitude of it namesake, who is a great friend of Brian Olson, and who provided opportunities which helped build the foundation of Cafe Intermezzo.
# Price: 14
#
# Category: Cocktails
# Item: Espresso Martini
# Description: Vanilla vodka, coffee liqueur, chocolate liqueur, and fresh espresso.
# Price: 13.5
#
# Category: Cocktails
# Item: French 75
# Description: Lemon, sugar, and Tanqueray Gin are shaken, strained and topped with champagne to recreate this timeless World War | era cocktail
# Price: 15
#
# Category: Cocktails
# Item: Peach Martini
# Description: Citrus vodka, peach schnapps, and peach nectar, topped with champagne.
# Price: 13
#
# Category: Cocktails
# Item: Sazerac
# Description: A New Orleans classic recreated with Redemption Rye, sugar, Peychaud’s bitters, and, of course, an absinthe rinse. Served neat.
# Price: 14
#
# Category: Cocktails
# Item: Aviation
# Description: Empress gin, maraschino liqueur, creme de violette, lemon juice, lemon peel.
# Price: 14
#
# Category: Cocktails
# Item: Old Fashioned
# Description: Sugar, bitters, orange slice, and cherry are paired with Michter’s Small Batch bourbon.
# Price: 16
#
# Category: Cocktails
# Item: B’Old Biddy
# Description: Bulleit Rye, paired with fresh lime juice, mint, cucumber, and St. Germain Elderflower liqueur. A refreshing cocktail that showcases the fresh ingredients and rye whiskey wonderfully. Served over ice.
# Price: 14.5
#
# Category: Cocktails
# Item: Paris on Fire
# Description: Grand Marnier, Chambord, pineapple juice, cranberry juice, and orange juice all over ice.
# Price: 14
#
# Category: Cocktails
# Item: Roasado Del Sol
# Description: Ron Zacapa Dark Rum, blackberry brandy, lemon juice, simple syrup, and a splash of orange juice
# Price: 13
#
# Category: Cocktails
# Item: Vi Olson “Inside Out”
# Description: A favorite of Brian Olson’s mother: a half lemon with a teaspoon of sugar, submerged in Tanqueray gin, muddled until its inside out, so that its essential oils flavor this delightful cocktail.
# Price: 14
#
# Category: Cocktails
# Item: Pimm’s Cup
# Description: Pimm’s #1, lemon, lime, orange, cucumber, and strawberry all muddled.
# Price: 14
#
# Category: Cocktails
# Item: Cucumber Martini
# Description: Hendrick’s gin, cucumber, lime and sugar. Stirred and strained. Crisp, bright and refreshing.
# Price: 15
#
# Category: Cocktails
# Item: Sidecar
# Description: Hennessy VSOP, orange liqueur, lemon and sugar. Shaken twice, strained, and served up.
# Price: 18

# %% [markdown]
# ## Cell 7: Prepare Data for Azure AI Search
#
# ### Description
# This function processes the structured JSON returned by GPT-4o, preparing it for ingestion into Azure AI Search.
# Each menu item is assigned a unique ID.

# %%
def sanitize_key(key):
    """Sanitize the document key to contain only valid characters."""
    return re.sub(r'[^a-zA-Z0-9_\-]', '_', key)

@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=5, max=60))
def generate_embedding(text):
    """
    Generate embeddings using Azure OpenAI with retry logic
    """
    response = aoai_client.embeddings.create(input=[text], model=aoai_embedding_deployment)
    return response.data[0].embedding

def prepare_data_for_azure_search(parsed_menu):
    """Transform parsed data for ingestion into Azure AI Search."""
    azure_search_documents = []
    for item in parsed_menu.items:
        combined_text = f"{item.category} {item.item} {item.description} {item.price}"
        document_key = sanitize_key(f"{item.category}_{item.item.replace(' ', '_')}".lower())
        azure_search_documents.append({
            "id": document_key,  # Use sanitized document key
            "category": item.category,
            "item": item.item,
            "description": item.description,
            "price": item.price,
            "embedding": generate_embedding(combined_text)  # Add embedding field
        })
    return azure_search_documents

# Transform structured data
documents_for_index = prepare_data_for_azure_search(parsed_menu)

for doc in documents_for_index:
    print(f"ID: {doc['id']}")
    print(f"Category: {doc['category']}")
    print(f"Item: {doc['item']}")
    print(f"Description: {doc['description']}")
    print(f"Price: {doc['price']}")
    print()  # Add a blank line between documents
# Out:
# ID: coffee_specialties_intermezzo_house_coffee
# Category: Coffee Specialties
# Item: Intermezzo House Coffee
# Description: Proudly serving Dancing Goats coffee. Priced for each kannchen
# Price: 4.00
#
# ID: coffee_specialties_coffee_infusion
# Category: Coffee Specialties
# Item: Coffee Infusion
# Description: “French Press” infused at your table (about 3 cups; please wait 2 minutes to push the press).
# Price: 5.00
#
# ID: coffee_specialties_espresso
# Category: Coffee Specialties
# Item: Espresso
# Description: la créme de café ... The essence of pure, rich coffee
# Price: 2.90
#
# ID: coffee_specialties_espresso_doppio
# Category: Coffee Specialties
# Item: Espresso Doppio
# Description: Double espresso
# Price: 4.00
#
# ID: coffee_specialties_caff__americano
# Category: Coffee Specialties
# Item: Caffé Americano
# Description: Double espresso diluted with purified water
# Price: 4.00
#
# ID: coffee_specialties_turkish_coffee
# Category: Coffee Specialties
# Item: Turkish Coffee
# Description: Pulverized light roast beans blended with cardamon and sugar, boiled 3 times, as served in Kolschitsky’s Coffeehouse in Vienna from 1683, and throughtout Arab and Greek nations. In contradiction to the famous story of Mr. Kolschitsky, the first recorded coffee-serving privilege in Vienna was granted in 1685 to an Armenian merchant named Deodato. (Notice: The grounds remain in the pot, some passing into your cup, making this extremely rich, sip slowly.)
# Price: 6.00
#
# ID: coffee_specialties_caf__cubano
# Category: Coffee Specialties
# Item: Café Cubano
# Description: Double-rich espresso extraction with caramelized sugar
# Price: 4.50
#
# ID: chilled_coffees_caf__johannes
# Category: Chilled Coffees
# Item: Café Johannes
# Description: Espresso doppio over two scoops of vanilla ice cream, with Schlag
# Price: 8.50
#
# ID: chilled_coffees_caff__alpine
# Category: Chilled Coffees
# Item: Caffé Alpine
# Description: Espresso, white chocolate and cream, all over ice
# Price: 6.50
#
# ID: chilled_coffees_granita_cappuccino
# Category: Chilled Coffees
# Item: Granita Cappuccino
# Description: Granules of sugar and ice mixed with espresso, cream, cocoa, and Schlag
# Price: 7.90
#
# ID: chilled_coffees_bailey_s_cappuccino
# Category: Chilled Coffees
# Item: Bailey’s Cappuccino
# Description: Espresso, créme de caffé, with steamed cream, Bailey’s Irish Cream Liqueur and Schlag
# Price: 12.50
#
# ID: chilled_coffees_caf__dolce_vita
# Category: Chilled Coffees
# Item: Café Dolce Vita
# Description: Cappuccino with Irish Cream and hazelnut liqueurs, over ice
# Price: 12.00
#
# ID: chilled_coffees_caf__nocciola
# Category: Chilled Coffees
# Item: Café Nocciola
# Description: Cappuccino Italiano with coffee and hazelnut liqueurs
# Price: 12.00
#
# ID: chilled_coffees_caf__royale
# Category: Chilled Coffees
# Item: Café Royale
# Description: Intermezzo House coffee with brandy and Schlag
# Price: 11.50
#
# ID: chilled_coffees_caf__salzburg
# Category: Chilled Coffees
# Item: Café Salzburg
# Description: Espresso, milk, chocolate, vanilla, and Tuaca Vanilla/Herb Liqueur
# Price: 12.00
#
# ID: chilled_coffees_caff__corretto
# Category: Chilled Coffees
# Item: Caffé Corretto
# Description: Espresso créme de café with 1 oz. Sambuca or Grappa served on the side
# Price: 11.00
#
# ID: chilled_coffees_caff__light___dark
# Category: Chilled Coffees
# Item: Caffé Light & Dark
# Description: Créme de Cocoa with espresso, cream and ice
# Price: 11.50
#
# ID: chilled_coffees_cappuccino_la_scala
# Category: Chilled Coffees
# Item: Cappuccino La Scala
# Description: Cappuccino Italaino with chocolate and almond liquer
# Price: 12.00
#
# ID: chilled_coffees_cioccolate_calda_firenze
# Category: Chilled Coffees
# Item: Cioccolate Calda Firenze
# Description: Hot Chocolate Deluxe with Tuaca Vanilla/ Herb liqueur.
# Price: 13.00
#
# ID: chilled_coffees_irish_coffee
# Category: Chilled Coffees
# Item: Irish Coffee
# Description: Café Intermezzo House Coffee, Irish Whiskey and whipped cream.
# Price: 11.50
#
# ID: chilled_coffees_the_joe_cartwright
# Category: Chilled Coffees
# Item: The Joe Cartwright
# Description: vu ~ pvorten Advockaat IQUEUr, vanilla ICe Cream, Espresso, and vanilla syrup. Ponderously great! In honor of a wonderful friend!
# Price: 13.00
#
# ID: chilled_coffees_kahlua_coffee
# Category: Chilled Coffees
# Item: Kahlua Coffee
# Description: Café Intermezzo House Coffee with Kahlua coffee liqueur (with or without Schlag)
# Price: 11.50
#
# ID: chilled_coffees_north_face
# Category: Chilled Coffees
# Item: North Face
# Description: Hot Chocolate Deluxe with Peppermint Schnapps, in a large cup.
# Price: 13.00
#
# ID: chilled_coffees_page_one
# Category: Chilled Coffees
# Item: Page One
# Description: Cappuccino with Hazelnut-chocolate spread and Hazelnut liqueur
# Price: 12.00
#
# ID: cappuccinos___caffe_lattes_cappuccino_italiano
# Category: Cappuccinos & Caffe Lattes
# Item: Cappuccino Italiano
# Description: Espresso and steamed cream with froth.
# Price: Classico (Reg) 5.00, Generoso (Lrg) 8.50
#
# ID: cappuccinos___caffe_lattes_intermezzo_cappuccino
# Category: Cappuccinos & Caffe Lattes
# Item: Intermezzo Cappuccino
# Description: Espresso, the essence of coffee, with steamed cream, cocoa, all topped with fresh whipped cream & cinnamon.
# Price: Classico (Reg) 5.90, Generoso (Lrg) 9.00
#
# ID: cappuccinos___caffe_lattes_caff__latte
# Category: Cappuccinos & Caffe Lattes
# Item: Caffé Latte
# Description: Espresso créme de café with steamed milk
# Price: Classico (Reg) 5.00, Generoso (Lrg) 8.50
#
# ID: cappuccinos___caffe_lattes_caff__intermezzo
# Category: Cappuccinos & Caffe Lattes
# Item: Caffé Intermezzo
# Description: Espresso with steamed cream, essence of almond, cocoa powder and almond slices.
# Price: Classico (Reg) 6.30, Generoso (Lrg) 9.50
#
# ID: cappuccinos___caffe_lattes_caramel_cappuccino
# Category: Cappuccinos & Caffe Lattes
# Item: Caramel Cappuccino
# Description: Espresso créme de caffé with steamed cream and caramel, topped with Schlag.
# Price: Classico (Reg) 6.30, Generoso (Lrg) 9.50
#
# ID: cappuccinos___caffe_lattes_cioccoloccino
# Category: Cappuccinos & Caffe Lattes
# Item: Cioccoloccino
# Description: Rich, pure Dutch Chocolate steamed in cream, added to espresso with Schlag and cocoa powder
# Price: Classico (Reg) 6.70, Generoso (Lrg) 9.80
#
# ID: cappuccinos___caffe_lattes_cioccoloccino_bianco
# Category: Cappuccinos & Caffe Lattes
# Item: Cioccoloccino Bianco
# Description: Dutch White chocolate steamed in cream and milk with espresso and Schlag.
# Price: Classico (Reg) 6.70, Generoso (Lrg) 10.00
#
# ID: cappuccinos___caffe_lattes_cubano_latte
# Category: Cappuccinos & Caffe Lattes
# Item: Cubano Latte
# Description: Café Cubano with steamed milk.
# Price: Classico (Reg) 5.99, Generoso (Lrg) 8.50
#
# ID: cappuccinos___caffe_lattes_cappuccino_gianduja
# Category: Cappuccinos & Caffe Lattes
# Item: Cappuccino Gianduja
# Description: (pronounced “John-do-ya”) Espresso with frothed cream, cocoa and hazelnut spread.
# Price: Classico (Reg) 7.20, Generoso (Lrg) 10.25
#
# ID: cappuccinos___caffe_lattes_cappuccino_l_amore
# Category: Cappuccinos & Caffe Lattes
# Item: Cappuccino L’Amore
# Description: Cappuccino with flavors of brandy and rum plue fresh Schlag and cocoa powder.
# Price: Classico (Reg) 6.30, Generoso (Lrg) 9.50
#
# ID: cappuccinos___caffe_lattes_capuchio_brio
# Category: Cappuccinos & Caffe Lattes
# Item: Capuchio Brio
# Description: espresso steamedcream, cinnamon, sugar, vanilla, almond oil, brandy and rum flavors, and orange extracts with Schlag. “Capuchio Brio” means “happy toga” which emanates from Capuchin Monks, after whom cappuccino was named.
# Price: Classico (Reg) 6.30, Generoso (Lrg) 9.50
#
# ID: cappuccinos___caffe_lattes_caff__bach
# Category: Cappuccinos & Caffe Lattes
# Item: Caffé Bach
# Description: Espresso with steamed cream and butterscotch, topped with Schlag and butterscotch.
# Price: Classico (Reg) 6.50, Generoso (Lrg) 9.50
#
# ID: cappuccinos___caffe_lattes_caff__mozart
# Category: Cappuccinos & Caffe Lattes
# Item: Caffé Mozart
# Description: Double espresso with fresh whipped cream and chocolate chips.
# Price: Classico (Reg) 5.50
#
# ID: hot_chocolate_hot_chocolate_deluxe
# Category: Hot Chocolate
# Item: Hot Chocolate DeLuxe
# Description: Rich steamed cream and milk, Dutch chocolate, fresh Schlag, and shaved dark chocolate
# Price: 7.90
#
# ID: hot_chocolate_intermezzo_hot_chocolate
# Category: Hot Chocolate
# Item: Intermezzo Hot Chocolate
# Description: Rich steamed cream, Dutch chocolate, fresh Schlag, and the essence of almond
# Price: 7.00
#
# ID: hot_chocolate_hot_chocolate_berlin
# Category: Hot Chocolate
# Item: Hot Chocolate Berlin
# Description: Hazelnut-chocolate spread with steamed cream
# Price: 8.50
#
# ID: hot_chocolate_white_hot_chocolate_deluxe
# Category: Hot Chocolate
# Item: White Hot Chocolate DeLuxe
# Description: Steamed cream and milk with Dutch white chocolate and vanilla
# Price: 7.90
#
# ID: hot_chocolate_mexican_hot_chocolate
# Category: Hot Chocolate
# Item: Mexican Hot Chocolate
# Description: Semi-sweet dark chocolate, mexican vanilla, milk and cinnamon.
# Price: 8.00
#
# ID: hot_chocolate_hot_chocolate_deluxe_truffle
# Category: Hot Chocolate
# Item: Hot Chocolate Deluxe Truffle
# Description: Hot Chocolate Deluxe with caramel syrup
# Price: 8.00
#
# ID: hot_chocolate_chocolate_peanut_butter_cup
# Category: Hot Chocolate
# Item: Chocolate Peanut Butter Cup
# Description: Steamed cream, Dutch chocolate, and peanut butter with fresh Schlag
# Price: 7.90
#
# ID: sodas_and_juices_coca-cola
# Category: Sodas and Juices
# Item: Coca-Cola
# Description: bottle 8 oz. classic (regular or diet)
# Price: 2.75
#
# ID: sodas_and_juices_sprite
# Category: Sodas and Juices
# Item: Sprite
# Description: 8 oz. bottle
# Price: 2.75
#
# ID: sodas_and_juices_iced_tea
# Category: Sodas and Juices
# Item: Iced Tea
# Description: House recipe blended and brewed with fresh leaf teas, unsweetened or sweetened
# Price: 2.95
#
# ID: sodas_and_juices_orange_juice
# Category: Sodas and Juices
# Item: Orange Juice
# Description:
# Price: 3.00
#
# ID: sodas_and_juices_panna_water
# Category: Sodas and Juices
# Item: Panna Water
# Description: (still), Italy, 500 ml.
# Price: 4.25
#
# ID: sodas_and_juices_panna_water
# Category: Sodas and Juices
# Item: Panna Water
# Description: 1 liter
# Price: 6.50
#
# ID: sodas_and_juices_san_pellegrino_water
# Category: Sodas and Juices
# Item: San Pellegrino Water
# Description: 500 ml.
# Price: 4.25
#
# ID: sodas_and_juices_san_pellegrino_water
# Category: Sodas and Juices
# Item: San Pellegrino Water
# Description: 1 liter
# Price: 6.50
#
# ID: beers_stella_artois
# Category: Beers
# Item: Stella Artois
# Description: Belgium, 12 oz.
# Price: 5.25
#
# ID: beers_sweetwater_420_extra_pale_ale
# Category: Beers
# Item: SweetWater 420 Extra Pale Ale
# Description: Atlanta, 5.6 %, 12 oz.
# Price: 5.50
#
# ID: beers_blue_moon_belgian_white
# Category: Beers
# Item: Blue Moon Belgian White
# Description: Denver, 12 oz.
# Price: 5.90
#
# ID: beers_erdinger_hefe-weizen
# Category: Beers
# Item: Erdinger Hefe-Weizen
# Description: (Wheat), Germany, 11.2 oz.
# Price: 7.50
#
# ID: beers_peroni__nastro_azzuro
# Category: Beers
# Item: Peroni, Nastro Azzuro
# Description: Italy, 11.2 oz
# Price: 6.00
#
# ID: beers_guinness_pub_draught
# Category: Beers
# Item: Guinness Pub Draught
# Description: Ireland (Nitrogen can) 14.9 oz.
# Price: 6.50
#
# ID: beers_heineken_0_0_non-_alcoholic
# Category: Beers
# Item: Heineken 0.0 Non- Alcoholic
# Description: 11 oz.
# Price: 6.25
#
# ID: beers_athletic_brewing_upside_dawn_0_0_non-alcoholic_beer
# Category: Beers
# Item: Athletic Brewing Upside Dawn 0.0 Non-Alcoholic Beer
# Description: 12 oz.
# Price: 6.50
#
# ID: teas_a_pot_of_hot_tea
# Category: Teas
# Item: A pot of hot tea
# Description: freshly infused to your order from whole leaf tea
# Price: 4.25
#
# ID: teas_a_pot_of_hot_water
# Category: Teas
# Item: A pot of hot water
# Description:
# Price: 1.50
#
# ID: teas_sugar_and_cream
# Category: Teas
# Item: Sugar and cream
# Description: are available upon request at no charge. Add Honey
# Price: $1
#
# ID: champagne_cocktails_champagne_flight
# Category: Champagne Cocktails
# Item: Champagne Flight
# Description: Choose 3 from any of the following champange cocktails
# Price: 22
#
# ID: champagne_cocktails_mimosa
# Category: Champagne Cocktails
# Item: Mimosa
# Description: Orange juice and sparkling wine
# Price: 10
#
# ID: champagne_cocktails_bellini
# Category: Champagne Cocktails
# Item: Bellini
# Description: Peach nectar and sparkling wine
# Price: 10
#
# ID: champagne_cocktails_hawaiian_mimosa
# Category: Champagne Cocktails
# Item: Hawaiian Mimosa
# Description: Pineapple juice, coconut rum and sparkling wine
# Price: 10
#
# ID: champagne_cocktails_buona_fortuna
# Category: Champagne Cocktails
# Item: Buona Fortuna
# Description: Strawberry puree, Strawberry schnapps with sparkling wine
# Price: 10
#
# ID: champagne_cocktails_cara_mia
# Category: Champagne Cocktails
# Item: Cara Mia
# Description: Mango nectar and sparkling wine
# Price: 10
#
# ID: champagne_cocktails_festa_limone
# Category: Champagne Cocktails
# Item: Festa Limone
# Description: Sparkling wine and Limoncello
# Price: 10
#
# ID: champagne_cocktails_kir_royale
# Category: Champagne Cocktails
# Item: Kir Royale
# Description: sparkling wine with Creme de Cassis
# Price: 10
#
# ID: champagne_cocktails_london_special
# Category: Champagne Cocktails
# Item: London Special
# Description: sparkling wine with bitters and sugar
# Price: 10
#
# ID: champagnes___sparkling_wines_lunetta__prosecco_brut
# Category: Champagnes & Sparkling Wines
# Item: Lunetta, Prosecco Brut
# Description: Italy, 187ml.
# Price: 16
#
# ID: champagnes___sparkling_wines_santa_maria__prose
# Category: Champagnes & Sparkling Wines
# Item: Santa Maria, Prose
# Description: Italy. Bottle 750 ml.
# Price: 38
#
# ID: champagnes___sparkling_wines_prince_de_richemont__brut_blanc_de_blancs
# Category: Champagnes & Sparkling Wines
# Item: Prince de Richemont, Brut Blanc de Blancs
# Description: France, . Glass
# Price: 9.25
#
# ID: champagnes___sparkling_wines_prince_de_richemont__brut_blanc_de_blancs
# Category: Champagnes & Sparkling Wines
# Item: Prince de Richemont, Brut Blanc de Blancs
# Description: Bottle 750ml.
# Price: 32
#
# ID: champagnes___sparkling_wines_villa_pozzi__sicilla_moscato
# Category: Champagnes & Sparkling Wines
# Item: Villa Pozzi, Sicilla Moscato
# Description: Italy, Glass
# Price: 10.50
#
# ID: champagnes___sparkling_wines_innocent_bystander_pink_moscato
# Category: Champagnes & Sparkling Wines
# Item: Innocent Bystander Pink Moscato
# Description:
# Price: 11
#
# ID: champagnes___sparkling_wines_domaine_chandon_brut
# Category: Champagnes & Sparkling Wines
# Item: Domaine Chandon Brut
# Description: Califronia, 187 ml.
# Price: 19
#
# ID: champagnes___sparkling_wines_freixenet_cordon_negro_brut
# Category: Champagnes & Sparkling Wines
# Item: Freixenet Cordon Negro Brut
# Description: Spain, 187ml.
# Price: 12
#
# ID: champagnes___sparkling_wines_freixenet_cordon_negro_brut
# Category: Champagnes & Sparkling Wines
# Item: Freixenet Cordon Negro Brut
# Description: 750ml.
# Price: 42
#
# ID: champagnes___sparkling_wines_veuve_de_clicquot
# Category: Champagnes & Sparkling Wines
# Item: Veuve de Clicquot
# Description: 375 ml.
# Price: 92
#
# ID: champagnes___sparkling_wines_mo_t_e_chandon
# Category: Champagnes & Sparkling Wines
# Item: Moét e Chandon
# Description: 750 ml.
# Price: 162
#
# ID: cocktails_the_bill_naegele_watertower_deluxe_martini
# Category: Cocktails
# Item: The Bill Naegele Watertower Deluxe Martini
# Description: A delicious concoction of Baileys Salted Caramel, coffee liqueurs, white and dark chocolate liqueurs, and vanilla vodka. Shaken with lots of ice, like the attitude of it namesake, who is a great friend of Brian Olson, and who provided opportunities which helped build the foundation of Cafe Intermezzo.
# Price: 14
#
# ID: cocktails_espresso_martini
# Category: Cocktails
# Item: Espresso Martini
# Description: Vanilla vodka, coffee liqueur, chocolate liqueur, and fresh espresso.
# Price: 13.5
#
# ID: cocktails_french_75
# Category: Cocktails
# Item: French 75
# Description: Lemon, sugar, and Tanqueray Gin are shaken, strained and topped with champagne to recreate this timeless World War | era cocktail
# Price: 15
#
# ID: cocktails_peach_martini
# Category: Cocktails
# Item: Peach Martini
# Description: Citrus vodka, peach schnapps, and peach nectar, topped with champagne.
# Price: 13
#
# ID: cocktails_sazerac
# Category: Cocktails
# Item: Sazerac
# Description: A New Orleans classic recreated with Redemption Rye, sugar, Peychaud’s bitters, and, of course, an absinthe rinse. Served neat.
# Price: 14
#
# ID: cocktails_aviation
# Category: Cocktails
# Item: Aviation
# Description: Empress gin, maraschino liqueur, creme de violette, lemon juice, lemon peel.
# Price: 14
#
# ID: cocktails_old_fashioned
# Category: Cocktails
# Item: Old Fashioned
# Description: Sugar, bitters, orange slice, and cherry are paired with Michter’s Small Batch bourbon.
# Price: 16
#
# ID: cocktails_b_old_biddy
# Category: Cocktails
# Item: B’Old Biddy
# Description: Bulleit Rye, paired with fresh lime juice, mint, cucumber, and St. Germain Elderflower liqueur. A refreshing cocktail that showcases the fresh ingredients and rye whiskey wonderfully. Served over ice.
# Price: 14.5
#
# ID: cocktails_paris_on_fire
# Category: Cocktails
# Item: Paris on Fire
# Description: Grand Marnier, Chambord, pineapple juice, cranberry juice, and orange juice all over ice.
# Price: 14
#
# ID: cocktails_roasado_del_sol
# Category: Cocktails
# Item: Roasado Del Sol
# Description: Ron Zacapa Dark Rum, blackberry brandy, lemon juice, simple syrup, and a splash of orange juice
# Price: 13
#
# ID: cocktails_vi_olson__inside_out_
# Category: Cocktails
# Item: Vi Olson “Inside Out”
# Description: A favorite of Brian Olson’s mother: a half lemon with a teaspoon of sugar, submerged in Tanqueray gin, muddled until its inside out, so that its essential oils flavor this delightful cocktail.
# Price: 14
#
# ID: cocktails_pimm_s_cup
# Category: Cocktails
# Item: Pimm’s Cup
# Description: Pimm’s #1, lemon, lime, orange, cucumber, and strawberry all muddled.
# Price: 14
#
# ID: cocktails_cucumber_martini
# Category: Cocktails
# Item: Cucumber Martini
# Description: Hendrick’s gin, cucumber, lime and sugar. Stirred and strained. Crisp, bright and refreshing.
# Price: 15
#
# ID: cocktails_sidecar
# Category: Cocktails
# Item: Sidecar
# Description: Hennessy VSOP, orange liqueur, lemon and sugar. Shaken twice, strained, and served up.
# Price: 18

# %% [markdown]
# ## Cell 8: Upload to Azure AI Search
#
# ### Description
# This cell defines and calls a function to upload the prepared data to Azure AI Search.
# Ensure the Azure AI Search index is properly configured before running this step.

# %%
def upload_documents_to_search(documents):
    batch_size = 15
    total_batches = (len(documents) + batch_size - 1) // batch_size  # Calculate total number of batches
    successful_uploads = 0

    for i in range(0, len(documents), batch_size):
        batch = documents[i:i + batch_size]
        try:
            # Upload the batch
            response = search_client.upload_documents(documents=batch)
            successful_uploads += len(batch)
            print(f"Uploaded batch {i // batch_size + 1}/{total_batches} successfully. Batch size: {len(batch)}")
        except HttpResponseError as e:
            print(f"Error uploading batch {i // batch_size + 1}/{total_batches}: {e}")
            # Log the problematic batch for further inspection
            # print(f"Problematic batch: {batch}")
            continue

    print(f"Embedding index created and documents uploaded successfully. Total successful uploads: {successful_uploads}/{len(documents)}")

upload_documents_to_search(documents_for_index)
# Out:
# Uploaded batch 1/7 successfully. Batch size: 15
# Uploaded batch 2/7 successfully. Batch size: 15
# Uploaded batch 3/7 successfully. Batch size: 15
# Uploaded batch 4/7 successfully. Batch size: 15
# Uploaded batch 5/7 successfully. Batch size: 15
# Uploaded batch 6/7 successfully. Batch size: 15
# Uploaded batch 7/7 successfully. Batch size: 7
# Embedding index created and documents uploaded successfully. Total successful uploads: 97/97

# %% [markdown]
# ## Cell 9: Final Summary
#
# ### Summary
# - Extracted text from the PDF file.
# - Parsed the text into structured JSON using GPT-4o.
# - Uploaded the structured data into Azure AI Search.
# The pipeline is now complete!
